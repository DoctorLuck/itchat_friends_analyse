# %%
from pyecharts import Map
import data_analyse.np_pd as data

# %%
from pyecharts import Pie
pie=Pie("饼图")
pie.add("",data.sex_type,data.sex_num,is_label_show=True)
pie.lll()
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="37fb899877af43ba934473bd8b03aced" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	         var myChart = ec.init(document.getElementById('37fb899877af43ba934473bd8b03aced'));
#          var option =  {
#     "title": [
#         {
#             "text": "\u997c\u56fe",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
# ...
