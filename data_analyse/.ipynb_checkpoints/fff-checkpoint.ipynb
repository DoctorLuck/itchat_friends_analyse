# %%
import np_pd

# %%
print(np_pd.province_name)
# Out:
# ['上海', '北京', '四川', '天津', '宁夏', '山东', '山西', '广东', '广西', '江苏', '江西', '河南', '浙江', '湖北', '湖南', '甘肃', '福建', '辽宁', '陕西', '黑龙江']

# %%
from pyecharts import Map
value = np_pd.province_name
attr = ["福建", "山东", "北京", "上海"]
map = Map("全国地图示例", width=1200, height=600)
map.add("", , np_pd.province_num, maptype='china', is_label_show=True)
map
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts/china'
#          }
#     });
# </script>
# <div id="509815e23e43448ca306ee22f6405382" style="width:1200px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'china' ],function(ec){
# 	         var myChart = ec.init(document.getElementById('509815e23e43448ca306ee22f6405382'));
#          var option =  {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5730\u56fe\u793a\u4f8b",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...
